# %% [markdown]
# # Heatmap Visualization of CNN

# %%
import torch 
from torch import nn
from torchvision import models, transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from PIL import Image
from io import BytesIO
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.12 (Paper Env) (Python 3.12.6)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.12 (Paper Env) (Python 3.12.6)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
resnet = models.resnet50(pretrained=True, weights="ImageNet1K_V1").to(device)
